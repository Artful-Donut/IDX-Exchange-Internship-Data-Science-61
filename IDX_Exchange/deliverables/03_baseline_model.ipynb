# %% [markdown]
# # Linear Regression Baseline Model
# Tasks:
# - Train a Linear Regression as the first model.
# - Evaluate using R² on the test set.
# - Record baseline results.
# - Deliverable: 03_baseline_model.ipynb.
#
# Using a mix between this (https://codesignal.com/learn/courses/data-exploration-and-baseline-modeling/lessons/building-and-evaluating-baseline-regression-models-1) site and my previous homework assignments
#
# Also may implement RMSE as well, just to see predictability of the model. We'll see though. https://codesignal.com/learn/courses/data-exploration-and-baseline-modeling/lessons/building-and-evaluating-baseline-regression-models-1

# %% [markdown]
# # Setup

# %%
# Importing modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# Importing CSVs

root = "C:/Users/donutii/Desktop/IDX-Exchange-Internship-Data-Science-61"
data_location = f"{root}/IDX_Exchange/deliverables"

testing_set = pd.read_csv(f'{data_location}/CRMLS_202605_testing_set.csv')
training_set = pd.read_csv(f'{data_location}/CRMLS_202505_202604_training_set.csv')

# %%
print(training_set.head())
# Out:
#    ViewYN  WaterfrontYN  BasementYN  PoolPrivateYN   CloseDate  ClosePrice  \
# 0    True         False       False          False  2025-05-11      6500.0
# 1    True         False       False          False  2025-05-29   1800000.0
# 2    True         False        True          False  2025-05-19   1200000.0
# 3   False         False       False          False  2025-05-27   2250000.0
# 4    True         False       False          False  2025-05-30   1425000.0
#
#     Latitude   Longitude  PropertyType  LivingArea  ...     HighSchool  \
# 0  33.475311 -117.708995             1      1500.0  ...  910620.588929
# 1  33.899427 -117.977995             0      3546.0  ...  910620.588929
# 2  34.095980 -118.221993             0      1162.0  ...  910620.588929
# 3  37.313093 -122.006414             0      1134.0  ...  910620.588929
# 4  33.884526 -117.778002             0      1672.0  ...  910620.588929
#
#    Levels  MainLevelBedrooms  NewConstructionYN  GarageSpaces  \
# 0     1.0                2.0              False           2.0
# 1     2.0                1.0              False           3.0
# 2     1.0                0.0              False           2.0
# 3     0.0                0.0              False           1.0
# 4     1.0                3.0              False           2.0
#
#    HighSchoolDistrict    PostalCode  AssociationFee  LotSizeSquareFeet  \
# 0        1.246703e+06  1.238480e+06             0.0             3870.0
# 1        9.834992e+05  8.845274e+05           310.0             7740.0
# 2        1.176251e+06  9.552026e+05             0.0             4697.0
# 3        1.176251e+06  3.368651e+06             0.0             5775.0
# 4        1.187789e+06  1.288978e+06           124.0             7500.0
#
#    HasUnparsedAddress
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
#
# [5 rows x 35 columns]

# %%
# Using this site as a reference https://realpython.com/linear-regression-in-python/#multiple-linear-regression-with-scikit-learn
# Splitting training set into X and Y

    # Y
target = training_set['ClosePrice']
target_testing = testing_set['ClosePrice']

    # X
vars = training_set.drop(columns=['ClosePrice', 'CloseDate'])
vars_testing = testing_set.drop(columns='ClosePrice')

# Train a model
model = LinearRegression().fit(vars, target)

# print results
r_sq = model.score(vars, target)

# print(f'{len(vars.columns)}')
print(f'R2 value: {r_sq}')
# Out:
# R2 value: 0.7078784840359003

# %%
print(f'Intercept: {model.intercept_}')
print(f'Coefficients:')

for c in range(len(vars.columns)):
    print(f'{vars.columns[c]}: {model.coef_[c]}')
# Out:
# Intercept: 1043150.5938302785
# Coefficients:
# ViewYN: 28422.874545303705
# WaterfrontYN: 233261.11559171078
# BasementYN: 67162.56508205748
# PoolPrivateYN: 68011.504628779
# Latitude: -29336.127668186662
# Longitude: -4060.568213015401
# PropertyType: -1239587.1330981907
# LivingArea: 0.3671457582801736
# AssociationFeeFrequency: -0.1181849272652471
# CountyOrParish: 0.05418051611923147
# ElementarySchool: 0.08986879121403035
# AttachedGarageYN: -61498.22280428521
# ParkingTotal: -5.447947371915479
# SubdivisionName: 0.1864318532860807
# YearBuilt: 1214.7985627718128
# BathroomsTotalInteger: 235278.8352181927
# City: 0.19693895745149348
# BuildingAreaTotal: -0.3458100885763997
# BedroomsTotal: 33297.96004894532
# StateOrProvince: -1.4121451777562406
# MiddleOrJuniorSchool: 0.05263816341266647
# FireplaceYN: 48625.06920121262
# Stories: -36723.295655764574
# HighSchool: 0.12300716475647278
# Levels: 8132.18580307669
# MainLevelBedrooms: 7614.256748424496
# NewConstructionYN: 83324.45958243991
# GarageSpaces: 752.7751799509894
# HighSchoolDistrict: 0.1268317903013667
# PostalCode: 0.561139761688537
# AssociationFee: 166.89808729403185
# LotSizeSquareFeet: 0.34601311657752376
# HasUnparsedAddress: -13591.553264030765

# %%
# validating on testing set:
r_sq = model.score(vars_testing, target_testing)

# print(f'{len(vars.columns)}')
print(f'R2 value: {r_sq}')
# Out:
# R2 value: 0.7218401646715831

# %% [markdown]
# todo: test month hyperparameter
